# %%
#right code begines here.
import  requests
import lxml
from bs4 import BeautifulSoup
from xlwt import *

url = "https://www.imdb.com/chart/top/"

headers = {'User-Agent' : 'Mozilla/5.0\
           (Macintosh; Intel Mac OS X 10_10_1) ApplleWebKit/537.36 (KHTML, like Gecko)Chrome/39.0.2171.95 Safari/537.36'} 

f = requests.get(url,headers)


soup = BeautifulSoup(f.content,'lxml')
table = soup.find('table', {'data-caller-name':'chart-top250movie'})
tr = table.find_all("tr")
print(tr)
movies_list=[]
num =0

# %%
workbook = Workbook(encoding = 'utf-8')
table = workbook.add_sheet('data',cell_overwrite_ok=True)
table.write(0 ,0, 'Number')#0 row o th cloumn
table.write(0, 1, 'movie_url')#0th row 1 st column
table.write(0, 2, 'movie_name')
table.write(0, 3 ,'movie_summary')
line = 1

# %%
for each_tr in tr:
    td = each_tr.find_all('td',{'class' : 'titleColumn'})
    #in each tr row find each td cell
    for each_td in td:
        print(each_td.text)
        ulink = each_td.a['href']
        url = "https://www.imdb.com" + ulink
        movies_list.append(url)
        num +=1
        movie_url = url
        movie_f = requests.get(movie_url,headers = headers)
        movie_soup = BeautifulSoup(movie_f.content, 'lxml')
        #movie_conent = movie_soup.find('span','role' : 'presentation')
        movie_content = movie_soup.find('span',{'data-testid' : 'plot-xl'})
        movie_title = movie_soup.find('h1')
        #print(num,url,'\n', =movie_content.string(movie_title))
        #print('Movie info :' +movie_content.string.strip())
        table.write(line, 0, num)
        table.write(line, 1, url)
        table.write(line, 2, movie_title.string.strip())
        table.write(line, 3, movie_content.string.strip())
        line =+1
        workbook.save('movies_top100.xls')
# Out:
#       1.
#       刺激1995
# (1994)
#
#
#       2.
#       教父
# (1972)
#
#
#       3.
#       黑暗騎士
# (2008)
#
#
#       4.
#       教父2
# (1974)
#
#
#       5.
#       十二怒漢
# (1957)
#
#
#       6.
#       辛德勒的名單
# (1993)
#
#
#       7.
#       魔戒三部曲：王者再臨
# (2003)
#
#
#       8.
#       黑色追緝令
# (1994)
#
#
#       9.
#       魔戒首部曲：魔戒現身
# (2001)
#
#
#       10.
#       黃昏三鏢客
# (1966)
#
#
#       11.
#       阿甘正傳
# (1994)
#
#
#       12.
#       鬥陣俱樂部
# (1999)
#
#
#       13.
#       全面啟動
# (2010)
#
#
#       14.
#       魔戒二部曲：雙城奇謀
# (2002)
#
#
#       15.
#       星際大戰五部曲：帝國大反擊
# (1980)
#
#
#       16.
#       駭客任務
# (1999)
#
#
#       17.
#       四海好傢伙
# (1990)
#
#
#       18.
#       飛越杜鵑窩
# (1975)
#
#
#       19.
#       火線追緝令
# (1995)
#
#
#       20.
#       七武士
# (1954)
#
#
#       21.
#       風雲人物
# (1946)
#
#
#       22.
#       沉默的羔羊
# (1991)
#
#
#       23.
#       無法無天
# (2002)
#
#
#       24.
#       搶救雷恩大兵
# (1998)
#
#
#       25.
#       美麗人生
# (1997)
#
#
#       26.
#       星際效應
# (2014)
#
#
#       27.
#       綠色奇蹟
# (1999)
#
#
#       28.
#       星際大戰
# (1977)
#
#
#       29.
#       魔鬼終結者2
# (1991)
#
#
#       30.
#       回到未來
# (1985)
#
#
#       31.
#       神隱少女
# (2001)
#
#
#       32.
#       驚魂記
# (1960)
#
#
#       33.
#       戰地琴人
# (2002)
#
#
#       34.
#       寄生上流
# (2019)
#
#
#       35.
#       終極追殺令
# (1994)
#
#
#       36.
#       獅子王
# (1994)
#
#
#       37.
#       神鬼戰士
# (2000)
#
#
#       38.
#       美國X檔案
# (1998)
#
#
#       39.
#       神鬼無間
# (2006)
#
#
#       40.
#       刺激驚爆點
# (1995)
#
#
#       41.
#       頂尖對決
# (2006)
#
#
#       42.
#       進擊的鼓手
# (2014)
#
#
#       43.
#       北非諜影
# (1942)
#
#
#       44.
#       逆轉人生
# (2011)
#
#
#       45.
#       切腹
# (1962)
#
#
#       46.
#       螢火蟲之墓
# (1988)
#
#
#       47.
#       摩登時代
# (1936)
#
#
#       48.
#       狂沙十萬里
# (1968)
#
#
#       49.
#       後窗
# (1954)
#
#
#       50.
#       城市之光
# (1931)
#
#
#       51.
#       異形
# (1979)
#
#
#       52.
#       新天堂樂園
# (1988)
#
#
#       53.
#       現代啟示錄
# (1979)
#
#
#       54.
#       記憶拼圖
# (2000)
#
#
#       55.
#       法櫃奇兵
# (1981)
#
#
#       56.
#       決殺令
# (2012)
#
#
#       57.
#       瓦力
# (2008)
#
#
#       58.
#       竊聽風暴
# (2006)
#
#
#       59.
#       日落大道
# (1950)
#
#
#       60.
#       光榮之路
# (1957)
#
#
#       61.
#       鬼店
# (1980)
#
#
#       62.
#       大獨裁者
# (1940)
#
#
#       63.
#       情婦
# (1957)
#
#
#       64.
#       復仇者聯盟：無限之戰
# (2018)
#
#
#       65.
#       異形2
# (1986)
#
#
#       66.
#       美國心玫瑰情
# (1999)
#
#
#       67.
#       蜘蛛人：新宇宙
# (2018)
#
#
#       68.
#       奇愛博士
# (1964)
#
#
#       69.
#       黑暗騎士：黎明昇起
# (2012)
#
#
#       70.
#       原罪犯
# (2003)
#
#
#       71.
#       小丑
# (2019)
#
#
#       72.
#       阿瑪迪斯
# (1984)
#
#
#       73.
#       玩具總動員
# (1995)
#
#
#       74.
#       惡棍特工
# (2009)
#
#
#       75.
#       梅爾吉勃遜之英雄本色
# (1995)
#
#
#       76.
#       可可夜總會
# (2017)
#
#
#       77.
#       從海底出擊
# (1981)
#
#
#       78.
#       捍衛戰士：獨行俠
# (2022)
#
#
#       79.
#       復仇者聯盟：終局之戰
# (2019)
#
#
#       80.
#       魔法公主
# (1997)
#
#
#       81.
#       四海兄弟
# (1984)
#
#
#       82.
#       心靈捕手
# (1997)
#
#
#       83.
#       你的名字
# (2016)
#
#
#       84.
#       噩夢輓歌
# (2000)
#
#
#       85.
#       玩具總動員3
# (2010)
#
#
#       86.
#       萬花嬉春
# (1952)
#
#
#       87.
#       三個傻瓜
# (2009)
#
#
#       88.
#       天國與地獄
# (1963)
#
#
#       89.
#       星際大戰六部曲：絕地大反攻
# (1983)
#
#
#       90.
#       2001：太空漫遊
# (1968)
#
#
#       91.
#       王牌冤家
# (2004)
#
#
#       92.
#       霸道橫行
# (1992)
#
#
#       93.
#       我想有個家
# (2018)
#
#
#       94.
#       謊言的烙印
# (2012)
#
#
#       95.
#       大國民
# (1941)
#
#
#       96.
#       阿拉伯的勞倫斯
# (1962)
#
#
#       97.
#       M就是兇手
# (1931)
#
#
#       98.
#       見證
# (1985)
#
#
#       99.
#       北西北
# (1959)
#
#
#       100.
#       迷魂記
# (1958)
#
#
#       101.
#       艾蜜莉的異想世界
# (2001)
#
#
#       102.
#       發條橘子
# (1971)
#
#
#       103.
#       公寓春光
# (1960)
#
#
#       104.
#       雙重賠償
# (1944)
#
#
#       105.
#       金甲部隊
# (1987)
#
#
#       106.
#       生之慾
# (1952)
#
#
#       107.
#       疤面煞星
# (1983)
#
#
#       108.
#       漢密爾頓
# (2020)
#
#
#       109.
#       刺激
# (1973)
#
#
#       110.
#       梅崗城故事
# (1962)
#
#
#       111.
#       烈火悍將
# (1995)
#
#
#       112.
#       天外奇蹟
# (2009)
#
#
#       113.
#       計程車司機
# (1976)
#
#
#       114.
#       烈火焚身
# (2010)
#
#
#       115.
#       大都會
# (1927)
#
#
#       116.
#       分居風暴
# (2011)
#
#
#       117.
#       鐵面特警隊
# (1997)
#
#
#       118.
#       偷拐搶騙
# (2000)
#
#
#       119.
#       單車失竊記
# (1948)
#
#
#       120.
#       終極警探
# (1988)
#
#
#       121.
#       聖戰奇兵
# (1989)
#
#
#       122.
#       1917
# (2019)
#
#
#       123.
#       心中的小星星
# (2007)
#
#
#       124.
#       帝國毀滅
# (2004)
#
#
#       125.
#       黃昏雙鏢客
# (1965)
#
#
#       126.
#       蝙蝠俠：開戰時刻
# (2005)
#
#
#       127.
#       我和我的冠軍女兒
# (2016)
#
#
#       128.
#       孤兒流浪記
# (1921)
#
#
#       129.
#       熱情如火
# (1959)
#
#
#       130.
#       彗星美人
# (1950)
#
#
#       131.
#       父親
# (2020)
#
#
#       132.
#       幸福綠皮書
# (2018)
#
#
#       133.
#       華爾街之狼
# (2013)
#
#
#       134.
#       紐倫堡大審
# (1961)
#
#
#       135.
#       亂
# (1985)
#
#
#       136.
#       賭國風雲
# (1995)
#
#
#       137.
#       羊男的迷宮
# (2006)
#
#
#       138.
#       殺無赦
# (1992)
#
#
#       139.
#       黑金企業
# (2007)
#
#
#       140.
#       蜘蛛人：無家日
# (2021)
#
#
#       141.
#       楚門的世界
# (1998)
#
#
#       142.
#       靈異第六感
# (1999)
#
#
#       143.
#       美麗境界
# (2001)
#
#
#       144.
#       大鏢客
# (1961)
#
#
#       145.
#       聖杯傳奇
# (1975)
#
#
#       146.
#       碧血金沙
# (1948)
#
#
#       147.
#       隔離島
# (2010)
#
#
#       148.
#       侏儸紀公園
# (1993)
#
#
#       149.
#       羅生門
# (1950)
#
#
#       150.
#       第三集中營
# (1963)
#
#
#       151.
#       追殺比爾
# (2003)
#
#
#       152.
#       險路勿近
# (2007)
#
#
#       153.
#       海底總動員
# (2003)
#
#
#       154.
#       象人
# (1980)
#
#
#       155.
#       唐人街
# (1974)
#
#
#       156.
#       突變第三型
# (1982)
#
#
#       157.
#       蠻牛
# (1980)
#
#
#       158.
#       亂世佳人
# (1939)
#
#
#       159.
#       V怪客
# (2005)
#
#
#       160.
#       腦筋急轉彎
# (2015)
#
#
#       161.
#       兩根槍管
# (1998)
#
#
#       162.
#       電話情殺案
# (1954)
#
#
#       163.
#       謎樣的雙眼
# (2009)
#
#
#       164.
#       霍爾的移動城堡
# (2004)
#
#
#       165.
#       桂河大橋
# (1957)
#
#
#       166.
#       意外
# (2017)
#
#
#       167.
#       猜火車
# (1996)
#
#
#       168.
#       勇者無敵
# (2011)
#
#
#       169.
#       經典老爺車
# (2008)
#
#
#       170.
#       冰血暴
# (1996)
#
#
#       171.
#       私法爭鋒
# (2013)
#
#
#       172.
#       龍貓
# (1988)
#
#
#       173.
#       登峰造擊
# (2004)
#
#
#       174.
#       神鬼交鋒
# (2002)
#
#
#       175.
#       淘金記
# (1925)
#
#
#       176.
#       天堂的孩子
# (1997)
#
#
#       177.
#       銀翼殺手
# (1982)
#
#
#       178.
#       岸上風雲
# (1954)
#
#
#       179.
#       黑獄亡魂
# (1949)
#
#
#       180.
#       自由之心
# (2013)
#
#
#       181.
#       愛在黎明破曉時
# (1995)
#
#
#       182.
#       野草莓
# (1957)
#
#
#       183.
#       哈利波特：死神的聖物2
# (2011)
#
#
#       184.
#       賓漢
# (1959)
#
#
#       185.
#       控制
# (2014)
#
#
#       186.
#       將軍號
# (1926)
#
#
#       187.
#       越戰獵鹿人
# (1978)
#
#
#       188.
#       歡迎來到布達佩斯大飯店
# (2014)
#
#
#       189.
#       以父之名
# (1993)
#
#
#       190.
#       亂世兒女
# (1975)
#
#
#       191.
#       恐懼的代價
# (1953)
#
#
#       192.
#       少年福爾摩斯
# (1924)
#
#
#       193.
#       華府風雲
# (1939)
#
#
#       194.
#       殺人回憶
# (2003)
#
#
#       195.
#       鋼鐵英雄
# (2016)
#
#
#       196.
#       克勞斯：聖誕節的秘密
# (2019)
#
#
#       197.
#       生命中最抓狂的小事
# (2014)
#
#
#       198.
#       第七封印
# (1957)
#
#
#       199.
#       不存在的房間
# (2015)
#
#
#       200.
#       瘋狂麥斯：憤怒道
# (2015)
#
#
#       201.
#       巧克力情緣
# (2009)
#
#
#       202.
#       馴龍高手
# (2010)
#
#
#       203.
#       謀殺綠腳趾
# (1998)
#
#
#       204.
#       怪獸電力公司
# (2001)
#
#
#       205.
#       大白鯊
# (1975)
#
#
#       206.
#       東京物語
# (1953)
#
#
#       207.
#       聖女貞德蒙難記
# (1928)
#
#
#       208.
#       春風化雨
# (1989)
#
#
#       209.
#       盧安達飯店
# (2004)
#
#
#       210.
#       賽道狂人
# (2019)
#
#
#       211.
#       洛基
# (1976)
#
#
#       212.
#       前進高棉
# (1986)
#
#
#       213.
#       媽的多重宇宙
# (2022)
#
#
#       214.
#       大地之歌
# (1955)
#
#
#       215.
#       站在我這邊
# (1986)
#
#
#       216.
#       魔鬼終結者
# (1984)
#
#
#       217.
#       驚爆焦點
# (2015)
#
#
#       218.
#       決戰終點線
# (2013)
#
#
#       219.
#       羅根
# (2017)
#
#
#       220.
#       料理鼠王
# (2007)
#
#
#       221.
#       螢光幕後
# (1976)
#
#
#       222.
#       阿拉斯加之死
# (2007)
#
#
#       223.
#       綠野仙蹤
# (1939)
#
#
#       224.
#       愛在日落巴黎時
# (2004)
#
#
#       225.
#       今天暫時停止
# (1993)
#
#
#       226.
#       大法師
# (1973)
#
#
#       227.
#       黃金時代
# (1946)
#
#
#       228.
#       生死問題
# (1942)
#
#
#       229.
#       超人特攻隊
# (2004)
#
#
#       230.
#       Jai Bhim
# (2021)
#
#
#       231.
#       阿爾及爾之戰
# (1966)
#
#
#       232.
#       忠犬小八
# (2009)
#
#
#       233.
#       怒火之花
# (1940)
#
#
#       234.
#       蝴蝶夢
# (1940)
#
#
#       235.
#       愛是一條狗
# (2000)
#
#
#       236.
#       吾父吾子
# (2005)
#
#
#       237.
#       神鬼奇航：鬼盜船魔咒
# (2003)
#
#
#       238.
#       恨
# (1995)
#
#
#       239.
#       鐵窗喋血
# (1967)
#
#
#       240.
#       四百擊
# (1959)
#
#
#       241.
#       假面
# (1966)
#
#
#       242.
#       一夜風流
# (1934)
#
#
#       243.
#       下女的誘惑
# (2016)
#
#
#       244.
#       萬世魔星
# (1979)
#
#
#       245.
#       真善美
# (1965)
#
#
#       246.
#       德蘇烏札拉
# (1975)
#
#
#       247.
#       甘地
# (1982)
#
#
#       248.
#       姊妹
# (2011)
#
#
#       249.
#       阿拉丁
# (1992)
#
#
#       250.
#       鐵巨人
# (1999)
